# %% [markdown]
# Attempting to follow https://ocetrac.readthedocs.io/en/latest/examples/cmip6.html
#
# Quickly fails I think because I don't have the right dependencies. I didn't take the time to debug.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import intake
from cmip6_preprocessing.preprocessing import combined_preprocessing
import ocetrac
from dask_gateway import Gateway
from dask.distributed import Client
from dask import delayed
import dask
dask.config.set({"array.slicing.split_large_chunks": False});
# Out:
# /Users/rwegener/.pyenv/versions/miniconda3-4.7.12/envs/mhw/lib/python3.8/site-packages/dask_gateway/client.py:21: FutureWarning: format_bytes is deprecated and will be removed in a future release. Please use dask.utils.format_bytes instead.
#   from distributed.utils import LoopRunner, format_bytes

# %%
# gateway = Gateway()
# cluster = gateway.new_cluster()
# cluster.adapt(minimum=1, maximum=20)
client = Client()
client
# Out:
# /Users/rwegener/.pyenv/versions/miniconda3-4.7.12/envs/mhw/lib/python3.8/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 63801 instead
#   warnings.warn(
# distributed.diskutils - INFO - Found stale lock file and directory '/Users/rwegener/repos/mhw-ocetrac-census/local/dask-worker-space/worker-nweel9yw', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/Users/rwegener/repos/mhw-ocetrac-census/local/dask-worker-space/worker-73tt_94y', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/Users/rwegener/repos/mhw-ocetrac-census/local/dask-worker-space/worker-33rolxzu', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/Users/rwegener/repos/mhw-ocetrac-census/local/dask-worker-space/worker-k2it16en', purging
# <Client: 'tcp://127.0.0.1:63802' processes=4 threads=8, memory=16.00 GiB>

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")

# create a query dictionary
query = col.search(experiment_id=['historical'], # all forcing of the recent past
                 table_id='Omon', # ocean monthly data
                 source_id='GFDL-CM4', # GFDL Climate Model 4
                 variable_id=['tos'], # temperature ocean surface
                 grid_label='gr', # regridded data on target grid
                )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/miniconda3-4.7.12/envs/mhw/lib/python3.8/site-packages/intake/__init__.py in __getattr__(attr)
#      60     try:
# ---> 61         return gl[attr]
#      62     except KeyError:
#
# KeyError: 'open_esm_datastore'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/f8/rh42xb3d1tnbw2bxsjwgym1c0000gn/T/ipykernel_15441/1111710211.py in <module>
# ----> 1 col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")
#       2
#       3 # create a query dictionary
#       4 query = col.search(experiment_id=['historical'], # all forcing of the recent past
#       5                  table_id='Omon', # ocean monthly data
#
# ~/.pyenv/versions/miniconda3-4.7.12/envs/mhw/lib/python3.8/site-packages/intake/__init__.py in __getattr__(attr)
#      61         return gl[attr]
#      62     except KeyError:
# ---> 63         raise AttributeError(attr)
#      64
#      65
#
# AttributeError: open_esm_datastore
